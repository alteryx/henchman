# %% [markdown]
# # About
# Welcome to the functionality examples notebook. This notebook is only intended for local use: it's a place to try out and explore the `henchman` api without worrying about what will render in html on github or in the docs.

# %%
import pandas as pd
import featuretools as ft

es = ft.demo.load_retail()

cutoff_times = pd.read_csv('../../../../Downloads/predict_may_sales.csv')[['customer_id', 'cutoff_time', 'total']]
cutoff_times['cutoff_time'] = pd.to_datetime(cutoff_times['cutoff_time'])

fm, features = ft.dfs(entityset=es, target_entity='customers', cutoff_time=cutoff_times, verbose=True)
# Out:
# Built 143 features
# Elapsed: 00:18 | Remaining: 00:00 | Progress: 100%|██████████| Calculated: 10/10 chunks

# %%
es
# Out:
# Entityset: demo_retail_data
#   Entities:
#     order_products [Rows: 401604, Columns: 7]
#     products [Rows: 3684, Columns: 3]
#     orders [Rows: 22190, Columns: 5]
#     customers [Rows: 4372, Columns: 2]
#   Relationships:
#     order_products.product_id -> products.product_id
#     order_products.order_id -> orders.order_id
#     orders.customer_id -> customers.customer_id

# %% [markdown]
# # Diagnostics

# %%
from henchman.diagnostics import overview, warnings, column_report, profile

# %%
overview(es['order_products'].df)
# Out:
# +--------------+
# |  Data Shape  |
# +--------------+
# Number of columns: 7
# Number of rows: 401604
#
# +------------------+
# |  Missing Values  |
# +------------------+
# Most values missing from column: 0
# Average missing values by column: 0.00
#
# +----------------+
# |  Memory Usage  |
# +----------------+
# Total memory used: 80.01 MB
# Average memory by column: 10.00 MB
#
# +--------------+
# |  Data Types  |
# +--------------+
#                 index
# 0
# int64               2
# datetime64[ns]      1
# float64             2
# object              2

# %%
column_report(es['order_products'].df)
# Out:
# +-------------------------+
# |  Object Column Summary  |
# +-------------------------+
#
# ## order_id ##
# Unique: 22190
# Mode: 576339, (matches 0.1% of rows)
#
# ## product_id ##
# Unique: 3684
# Mode: 85123A, (matches 0.5% of rows)
#
# +-----------------------+
# |  Time Column Summary  |
# +-----------------------+
#
# ## order_date ##
# Last Time: 2011-12-09 12:50:00
# First Time: 2010-12-01 08:26:00
#
# +--------------------------+
# |  Numeric Column Summary  |
# +--------------------------+
#
# ## order_product_id ##
# Maximum: 401603, Minimum: 0, Mean: 200801.50
# Quartile 3: 301202.25 | Median: 200801.50| Quartile 1: 100400.75
#
# ## quantity ##
# Maximum: 80995, Minimum: -80995, Mean: 12.18
# Quartile 3: 12.00 | Median: 5.00| Quartile 1: 2.00
#
# ## unit_price ##
# Maximum: 64300.5, Minimum: 0.0, Mean: 5.73
# Quartile 3: 6.19 | Median: 3.22| Quartile 1: 2.06
#
# ## total ##
# Maximum: 277974.84, Minimum: -277974.84, Mean: 34.01
# Quartile 3: 32.67 | Median: 19.30| Quartile 1: 7.01

# %%
warnings(fm)
# Out:
# +------------+
# |  Warnings  |
# +------------+
# COUNT(orders) and NUM_UNIQUE(orders.MODE(order_products.product_id)) are linearly correlated: 0.968
# COUNT(orders) and NUM_UNIQUE(orders.DAY(first_order_products_time)) are linearly correlated: 0.938
# SUM(order_products.quantity) and SUM(order_products.total) are linearly correlated: 0.923
# STD(order_products.quantity) and STD(orders.MAX(order_products.quantity)) are linearly correlated: 0.931
# STD(order_products.unit_price) and MEAN(order_products.unit_price) are linearly correlated: 0.980
# STD(order_products.unit_price) and STD(orders.MAX(order_products.unit_price)) are linearly correlated: 0.923
# STD(order_products.unit_price) and STD(orders.MIN(order_products.unit_price)) are linearly correlated: 0.922
# STD(order_products.unit_price) and STD(orders.MEAN(order_products.unit_price)) are linearly correlated: 0.928
# STD(order_products.unit_price) and MEAN(orders.MAX(order_products.unit_price)) are linearly correlated: 0.941
# STD(order_products.unit_price) and MEAN(orders.MIN(order_products.unit_price)) are linearly correlated: 0.978
# STD(order_products.unit_price) and MEAN(orders.MEAN(order_products.unit_price)) are linearly correlated: 0.985
# STD(order_products.total) and STD(orders.MAX(order_products.total)) are linearly correlated: 0.916
# MAX(order_products.quantity) and MAX(orders.STD(order_products.quantity)) are linearly correlated: 0.928
# MAX(order_products.unit_price) and STD(orders.MAX(order_products.unit_price)) are linearly correlated: 0.956
# MAX(order_products.unit_price) and STD(orders.MIN(order_products.unit_price)) are linearly correlated: 0.900
# MAX(order_products.unit_price) and STD(orders.MEAN(order_products.unit_price)) are linearly correlated: 0.922
# MAX(order_products.unit_price) and MAX(orders.MIN(order_products.unit_price)) are linearly correlated: 0.938
# MAX(order_products.unit_price) and MAX(orders.MEAN(order_products.unit_price)) are linearly correlated: 0.965
# MAX(order_products.total) and STD(orders.MAX(order_products.total)) are linearly correlated: 0.937
# MAX(order_products.total) and MAX(orders.MEAN(order_products.total)) are linearly correlated: 0.905
# MIN(order_products.quantity) and STD(orders.MIN(order_products.quantity)) are linearly correlated: -0.957
# MIN(order_products.quantity) and STD(orders.MEAN(order_products.quantity)) are linearly correlated: -0.946
# MIN(order_products.quantity) and MIN(orders.MAX(order_products.quantity)) are linearly correlated: 0.993
# MIN(order_products.quantity) and MIN(orders.MEAN(order_products.quantity)) are linearly correlated: 0.999
# MIN(order_products.total) and MIN(orders.MEAN(order_products.total)) are linearly correlated: 0.945
# MEAN(order_products.unit_price) and MEAN(orders.MAX(order_products.unit_price)) are linearly correlated: 0.903
# MEAN(order_products.unit_price) and MEAN(orders.MIN(order_products.unit_price)) are linearly correlated: 0.961
# MEAN(order_products.unit_price) and MEAN(orders.MEAN(order_products.unit_price)) are linearly correlated: 0.967
# MEAN(order_products.total) and MEAN(orders.MEAN(order_products.total)) are linearly correlated: 0.964
# COUNT(order_products) and NUM_UNIQUE(order_products.product_id) are linearly correlated: 0.949
# COUNT(order_products) and SUM(orders.SKEW(order_products.quantity)) are linearly correlated: 0.900
# COUNT(order_products) and SUM(orders.SKEW(order_products.unit_price)) are linearly correlated: 0.914
# COUNT(order_products) and SUM(orders.SKEW(order_products.total)) are linearly correlated: 0.908
# COUNT(order_products) and SUM(orders.NUM_UNIQUE(order_products.product_id)) are linearly correlated: 1.000
# NUM_UNIQUE(order_products.product_id) and SUM(orders.NUM_UNIQUE(order_products.product_id)) are linearly correlated: 0.947
# YEAR(first_orders_time) and MONTH(first_orders_time) are linearly correlated: -0.987
# YEAR(first_orders_time) and NUM_UNIQUE(orders.YEAR(first_order_products_time)) are linearly correlated: -0.908
# SUM(orders.STD(order_products.total)) and SUM(orders.MAX(order_products.total)) are linearly correlated: 0.950
# SUM(orders.STD(order_products.total)) and MAX(orders.STD(order_products.total)) are linearly correlated: 0.923
# SUM(orders.MAX(order_products.quantity)) and SUM(orders.MEAN(order_products.quantity)) are linearly correlated: 0.928
# SUM(orders.MAX(order_products.unit_price)) and SUM(orders.MIN(order_products.unit_price)) are linearly correlated: 0.982
# SUM(orders.MAX(order_products.unit_price)) and SUM(orders.MEAN(order_products.unit_price)) are linearly correlated: 0.990
# SUM(orders.MAX(order_products.total)) and SUM(orders.MEAN(order_products.total)) are linearly correlated: 0.932
# SUM(orders.SKEW(order_products.quantity)) and SUM(orders.SKEW(order_products.total)) are linearly correlated: 0.929
# SUM(orders.SKEW(order_products.quantity)) and SUM(orders.NUM_UNIQUE(order_products.product_id)) are linearly correlated: 0.900
# SUM(orders.SKEW(order_products.unit_price)) and SUM(orders.NUM_UNIQUE(order_products.product_id)) are linearly correlated: 0.916
# SUM(orders.SKEW(order_products.total)) and SUM(orders.NUM_UNIQUE(order_products.product_id)) are linearly correlated: 0.909
# SUM(orders.MIN(order_products.quantity)) and SUM(orders.MEAN(order_products.quantity)) are linearly correlated: 0.954
# SUM(orders.MIN(order_products.unit_price)) and SUM(orders.MEAN(order_products.unit_price)) are linearly correlated: 0.998
# SUM(orders.MIN(order_products.unit_price)) and MAX(orders.MIN(order_products.unit_price)) are linearly correlated: 0.934
# SUM(orders.MIN(order_products.unit_price)) and MAX(orders.MEAN(order_products.unit_price)) are linearly correlated: 0.927
# SUM(orders.MIN(order_products.total)) and SUM(orders.MEAN(order_products.total)) are linearly correlated: 0.957
# SUM(orders.MEAN(order_products.unit_price)) and MAX(orders.MIN(order_products.unit_price)) are linearly correlated: 0.930
# SUM(orders.MEAN(order_products.unit_price)) and MAX(orders.MEAN(order_products.unit_price)) are linearly correlated: 0.927
# STD(orders.SUM(order_products.total)) and MAX(orders.SUM(order_products.total)) are linearly correlated: 0.948
# STD(orders.MAX(order_products.quantity)) and STD(orders.MIN(order_products.quantity)) are linearly correlated: 0.940
# STD(orders.MAX(order_products.quantity)) and STD(orders.MEAN(order_products.quantity)) are linearly correlated: 0.967
# STD(orders.MAX(order_products.unit_price)) and STD(orders.MIN(order_products.unit_price)) are linearly correlated: 0.954
# STD(orders.MAX(order_products.unit_price)) and STD(orders.MEAN(order_products.unit_price)) are linearly correlated: 0.970
# STD(orders.MAX(order_products.unit_price)) and MAX(orders.MIN(order_products.unit_price)) are linearly correlated: 0.917
# STD(orders.MAX(order_products.unit_price)) and MAX(orders.MEAN(order_products.unit_price)) are linearly correlated: 0.935
# STD(orders.MAX(order_products.unit_price)) and MEAN(orders.MAX(order_products.unit_price)) are linearly correlated: 0.905
# STD(orders.MAX(order_products.unit_price)) and MEAN(orders.MIN(order_products.unit_price)) are linearly correlated: 0.915
# STD(orders.MAX(order_products.unit_price)) and MEAN(orders.MEAN(order_products.unit_price)) are linearly correlated: 0.926
# STD(orders.MAX(order_products.total)) and STD(orders.MEAN(order_products.total)) are linearly correlated: 0.929
# STD(orders.MIN(order_products.quantity)) and STD(orders.MEAN(order_products.quantity)) are linearly correlated: 0.994
# STD(orders.MIN(order_products.quantity)) and MIN(orders.MAX(order_products.quantity)) are linearly correlated: -0.950
# STD(orders.MIN(order_products.quantity)) and MIN(orders.MEAN(order_products.quantity)) are linearly correlated: -0.955
# STD(orders.MIN(order_products.unit_price)) and STD(orders.MEAN(order_products.unit_price)) are linearly correlated: 0.996
# STD(orders.MIN(order_products.unit_price)) and MAX(orders.MIN(order_products.unit_price)) are linearly correlated: 0.962
# STD(orders.MIN(order_products.unit_price)) and MAX(orders.MEAN(order_products.unit_price)) are linearly correlated: 0.954
# STD(orders.MIN(order_products.unit_price)) and MEAN(orders.MIN(order_products.unit_price)) are linearly correlated: 0.959
# STD(orders.MIN(order_products.unit_price)) and MEAN(orders.MEAN(order_products.unit_price)) are linearly correlated: 0.957
# STD(orders.MIN(order_products.total)) and STD(orders.MEAN(order_products.total)) are linearly correlated: 0.987
# STD(orders.MIN(order_products.total)) and MAX(orders.MIN(order_products.total)) are linearly correlated: 0.922
# STD(orders.MIN(order_products.total)) and MAX(orders.MEAN(order_products.total)) are linearly correlated: 0.910
# STD(orders.MEAN(order_products.quantity)) and MIN(orders.MAX(order_products.quantity)) are linearly correlated: -0.936
# STD(orders.MEAN(order_products.quantity)) and MIN(orders.MEAN(order_products.quantity)) are linearly correlated: -0.943
# STD(orders.MEAN(order_products.unit_price)) and MAX(orders.MIN(order_products.unit_price)) are linearly correlated: 0.958
# STD(orders.MEAN(order_products.unit_price)) and MAX(orders.MEAN(order_products.unit_price)) are linearly correlated: 0.961
# STD(orders.MEAN(order_products.unit_price)) and MEAN(orders.MIN(order_products.unit_price)) are linearly correlated: 0.955
# STD(orders.MEAN(order_products.unit_price)) and MEAN(orders.MEAN(order_products.unit_price)) are linearly correlated: 0.957
# STD(orders.MEAN(order_products.total)) and MAX(orders.MIN(order_products.total)) are linearly correlated: 0.920
# STD(orders.MEAN(order_products.total)) and MAX(orders.MEAN(order_products.total)) are linearly correlated: 0.926
# STD(orders.COUNT(order_products)) and STD(orders.NUM_UNIQUE(order_products.product_id)) are linearly correlated: 0.999
# MAX(orders.MIN(order_products.quantity)) and MAX(orders.MEAN(order_products.quantity)) are linearly correlated: 0.950
# MAX(orders.MIN(order_products.unit_price)) and MAX(orders.MEAN(order_products.unit_price)) are linearly correlated: 0.993
# MAX(orders.MIN(order_products.total)) and MAX(orders.MEAN(order_products.total)) are linearly correlated: 0.985
# MAX(orders.COUNT(order_products)) and MAX(orders.NUM_UNIQUE(order_products.product_id)) are linearly correlated: 0.999
# SKEW(orders.COUNT(order_products)) and SKEW(orders.NUM_UNIQUE(order_products.product_id)) are linearly correlated: 0.998
# MIN(orders.SUM(order_products.quantity)) and MIN(orders.MAX(order_products.quantity)) are linearly correlated: 0.904
# MIN(orders.MAX(order_products.quantity)) and MIN(orders.MEAN(order_products.quantity)) are linearly correlated: 0.997
# MIN(orders.MAX(order_products.total)) and MIN(orders.MEAN(order_products.total)) are linearly correlated: 0.956
# MIN(orders.COUNT(order_products)) and MIN(orders.NUM_UNIQUE(order_products.product_id)) are linearly correlated: 1.000
# MEAN(orders.MAX(order_products.quantity)) and MEAN(orders.MEAN(order_products.quantity)) are linearly correlated: 0.919
# MEAN(orders.MAX(order_products.unit_price)) and MEAN(orders.MIN(order_products.unit_price)) are linearly correlated: 0.909
# MEAN(orders.MAX(order_products.unit_price)) and MEAN(orders.MEAN(order_products.unit_price)) are linearly correlated: 0.929
# MEAN(orders.MAX(order_products.total)) and MEAN(orders.MEAN(order_products.total)) are linearly correlated: 0.910
# MEAN(orders.MIN(order_products.quantity)) and MEAN(orders.MEAN(order_products.quantity)) are linearly correlated: 0.958
# MEAN(orders.MIN(order_products.unit_price)) and MEAN(orders.MEAN(order_products.unit_price)) are linearly correlated: 0.997
# MEAN(orders.MIN(order_products.total)) and MEAN(orders.MEAN(order_products.total)) are linearly correlated: 0.938
# MEAN(orders.COUNT(order_products)) and MEAN(orders.NUM_UNIQUE(order_products.product_id)) are linearly correlated: 0.999
# NUM_UNIQUE(orders.MODE(order_products.product_id)) and NUM_UNIQUE(orders.DAY(first_order_products_time)) are linearly correlated: 0.912
# MODE(order_products.product_id) has many unique values: 397
# MODE(orders.MODE(order_products.product_id)) has many unique values: 306

# %% [markdown]
# # Plotting

# %%
from henchman.plotting import show
from henchman.plotting import (feature_importances, histogram, piechart, scatter, timeseries)

# %%
show(piechart(es['orders'].df['cancelled']), title='Cancelled Orders')
# Out:
# <script src="http://localhost:52174/autoload.js?bokeh-autoload-element=15b88289-36be-4015-b2e1-3f0242ac1213&bokeh-absolute-url=http://localhost:52174&resources=none" id="15b88289-36be-4015-b2e1-3f0242ac1213"></script>

# %%
show(piechart(es['orders'].df['country'], mergepast=10), height=400, width=500)
# Out:
# <script src="http://localhost:52176/autoload.js?bokeh-autoload-element=66c70050-06e0-4ffa-9aee-e3d2e4d0de62&bokeh-absolute-url=http://localhost:52176&resources=none" id="66c70050-06e0-4ffa-9aee-e3d2e4d0de62"></script>

# %%
show(timeseries(es['customers'].df['first_orders_time'], es['customers'].df['customer_id'], 
                n_bins=20, aggregate='count'), 
     width=900, height=300)
# Out:
# <script src="http://localhost:52177/autoload.js?bokeh-autoload-element=ee474fd3-392c-460d-bb36-b6f01dcca100&bokeh-absolute-url=http://localhost:52177&resources=none" id="ee474fd3-392c-460d-bb36-b6f01dcca100"></script>

# %%
show(timeseries(es['order_products'].df['order_date'], es['order_products'].df['total'], 
                aggregate='sum', n_bins=12), 
     width=900, height=300)
# Out:
# <script src="http://localhost:52180/autoload.js?bokeh-autoload-element=0c21e987-fedc-4bc2-b84f-970ef571d3b4&bokeh-absolute-url=http://localhost:52180&resources=none" id="0c21e987-fedc-4bc2-b84f-970ef571d3b4"></script>

# %%
show(scatter(es['orders'].df['cancelled'], es['orders'].df['cancelled'], 
             agg=es['orders'].df['country'], hover=True, aggregate='mean'), 
     title='Cancelled by country', x_axis='Cancelled', y_axis='Cancelled', height=300, width=300)
# Out:
# <script src="http://localhost:52181/autoload.js?bokeh-autoload-element=082ac4eb-1759-4215-be34-87f99f4c0103&bokeh-absolute-url=http://localhost:52181&resources=none" id="082ac4eb-1759-4215-be34-87f99f4c0103"></script>

# %% [markdown]
# # Selection

# %%
from henchman.selection import RandomSelect, Dendrogram

# %%
from henchman.learning import inplace_encoder
X = inplace_encoder(fm.copy())
y = X.pop('total')
y = y > 1000
# Out:
# /Users/featurelabs07/miniconda3/envs/python36env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
selector_1 = RandomSelect(n_feats=10)
selector_1.fit(X)
selector_1.transform(X).head()
# Out:
#              MAX(orders.STD(order_products.quantity))  \
# customer_id
# 12372.0                                      7.194442
# 12395.0                                     46.231303
# 12399.0                                      7.527284
# 12414.0                                     15.226293
# 12415.0                                     94.897294
#
#              SUM(orders.MAX(order_products.total))  \
# customer_id
# 12372.0                                     78.705
# 12395.0                                    329.010
# 12399.0                                     33.660
# 12414.0                                    196.680
# 12415.0                                   4521.330
#
#              SKEW(orders.SUM(order_products.quantity))  \
# customer_id
# 12372.0                                       0.000000
# 12395.0                                       0.189633
# 12399.0                                       0.000000
# 12414.0                                       0.000000
# 12415.0                                       0.638199
#
#              MAX(order_products.unit_price)  \
# customer_id
# 12372.0                               29.70
# 12395.0                               29.70
# 12399.0                               24.75
# 12414.0                               66.00
# 12415.0                              577.50
#
#              STD(orders.SKEW(order_products.quantity))  \
# customer_id
# 12372.0                                       0.000000
# 12395.0                                       0.708551
# 12399.0                                       0.000000
# 12414.0                                       0.122809
# 12415.0                                       1.128444
#
#              MAX(orders.SKEW(order_products.quantity))  \
# customer_id
# 12372.0                                       0.777519
# 12395.0                                       2.059801
# 12399.0                                      -0.796031
# 12414.0                                       0.587105
# 12415.0                                       3.159390
#
#              NUM_UNIQUE(orders.MODE(order_products.product_id))  \
# customer_id
# 12372.0                                                      1
# 12395.0                                                      5
# 12399.0                                                      1
# 12414.0                                                      2
# 12415.0                                                      6
#
#              SKEW(orders.COUNT(order_products))  \
# customer_id
# 12372.0                                0.000000
# 12395.0                               -0.152923
# 12399.0                                0.000000
# 12414.0                                0.000000
# 12415.0                                0.522861
#
#              SUM(orders.MIN(order_products.unit_price))  \
# customer_id
# 12372.0                                          0.6930
# 12395.0                                         15.9225
# 12399.0                                          0.6930
# 12414.0                                          1.2540
# 12415.0                                        589.5615
#
#              STD(order_products.total)
# customer_id
# 12372.0                      15.926582
# 12395.0                      28.204842
# 12399.0                       5.284180
# 12414.0                      34.122594
# 12415.0                     270.167331

# %%
selector_2 = Dendrogram(X, max_threshes=500)
# Out:
# 100%|██████████| 482/482 [00:11<00:00, 42.93it/s]
# 100%|██████████| 482/482 [00:06<00:00, 76.76it/s]

# %%
from henchman.plotting import dendrogram
show(dendrogram(selector_2))
# Out:
# <script src="http://localhost:52184/autoload.js?bokeh-autoload-element=7a8ea944-2247-493c-ae31-3c809c475824&bokeh-absolute-url=http://localhost:52184&resources=none" id="7a8ea944-2247-493c-ae31-3c809c475824"></script>

# %%
selector_2._shuffle_all_representatives()

# %%
X_p = selector_2.transform(X, n_feats=80)
X_p.head()
# Out:
# There are 80 distinct connected componentsat thresh step 8 in the Dendrogram
# You might also be interested in 84 components at step 7
#              NUM_UNIQUE(orders.MODE(order_products.product_id))  \
# customer_id
# 12372.0                                                      1
# 12395.0                                                      5
# 12399.0                                                      1
# 12414.0                                                      2
# 12415.0                                                      6
#
#              PERCENT_TRUE(orders.cancelled)  NUM_UNIQUE(orders.country)  \
# customer_id
# 12372.0                            0.000000                           1
# 12395.0                            0.333333                           1
# 12399.0                            0.000000                           1
# 12414.0                            0.000000                           1
# 12415.0                            0.285714                           1
#
#              MODE(orders.country)  SUM(order_products.total)  \
# customer_id
# 12372.0                         4                   658.7130
# 12395.0                         2                  2013.2145
# 12399.0                         2                   475.2825
# 12414.0                         1                   654.3240
# 12415.0                         0                 62038.4160
#
#              SUM(order_products.unit_price)  \
# customer_id
# 12372.0                            105.4845
# 12395.0                            288.4200
# 12399.0                             54.6150
# 12414.0                            157.2615
# 12415.0                           1475.8920
#
#              MIN(orders.MEAN(order_products.quantity))  \
# customer_id
# 12372.0                                      11.200000
# 12395.0                                      -3.000000
# 12399.0                                      18.200000
# 12414.0                                      20.714286
# 12415.0                                    -100.000000
#
#              MEAN(orders.MEAN(order_products.unit_price))  \
# customer_id
# 12372.0                                          5.274225
# 12395.0                                          5.432045
# 12399.0                                          2.730750
# 12414.0                                         13.535893
# 12415.0                                         85.987048
#
#              STD(orders.MEAN(order_products.total))  \
# customer_id
# 12372.0                                    0.000000
# 12395.0                                   27.777604
# 12399.0                                    0.000000
# 12414.0                                   21.940286
# 12415.0                                  389.398995
#
#              MAX(orders.STD(order_products.quantity))  \
# customer_id
# 12372.0                                      7.194442
# 12395.0                                     46.231303
# 12399.0                                      7.527284
# 12414.0                                     15.226293
# 12415.0                                     94.897294
#
#                                   ...                         \
# customer_id                       ...
# 12372.0                           ...
# 12395.0                           ...
# 12399.0                           ...
# 12414.0                           ...
# 12415.0                           ...
#
#              MEAN(orders.SKEW(order_products.unit_price))  \
# customer_id
# 12372.0                                          2.949180
# 12395.0                                          1.513774
# 12399.0                                          3.877687
# 12414.0                                          1.749444
# 12415.0                                          0.760533
#
#              MEAN(orders.SKEW(order_products.total))  \
# customer_id
# 12372.0                                     1.367421
# 12395.0                                     0.722533
# 12399.0                                     0.172201
# 12414.0                                     0.117086
# 12415.0                                     1.043787
#
#              MEAN(orders.NUM_UNIQUE(order_products.product_id))  \
# customer_id
# 12372.0                                              20.000000
# 12395.0                                               9.500000
# 12399.0                                              20.000000
# 12414.0                                               6.000000
# 12415.0                                              28.857143
#
#              NUM_UNIQUE(orders.MONTH(first_order_products_time))  \
# customer_id
# 12372.0                                                      1
# 12395.0                                                      4
# 12399.0                                                      1
# 12414.0                                                      2
# 12415.0                                                      4
#
#              NUM_UNIQUE(orders.WEEKDAY(first_order_products_time))  \
# customer_id
# 12372.0                                                      1
# 12395.0                                                      2
# 12399.0                                                      1
# 12414.0                                                      2
# 12415.0                                                      4
#
#              MODE(orders.MODE(order_products.product_id))  \
# customer_id
# 12372.0                                                80
# 12395.0                                                70
# 12399.0                                                73
# 12414.0                                                32
# 12415.0                                                55
#
#              MODE(orders.DAY(first_order_products_time))  \
# customer_id
# 12372.0                                               16
# 12395.0                                                3
# 12399.0                                               23
# 12414.0                                                2
# 12415.0                                                3
#
#              MODE(orders.YEAR(first_order_products_time))  \
# customer_id
# 12372.0                                              2011
# 12395.0                                              2011
# 12399.0                                              2011
# 12414.0                                              2011
# 12415.0                                              2011
#
#              MODE(orders.MONTH(first_order_products_time))  \
# customer_id
# 12372.0                                                  2
# 12395.0                                                  2
# 12399.0                                                  3
# 12414.0                                                  2
# 12415.0                                                  1
#
#              MODE(orders.WEEKDAY(first_order_products_time))
# customer_id
# 12372.0                                                    2
# 12395.0                                                    4
# 12399.0                                                    2
# 12414.0                                                    1
# 12415.0                                                    3
#
# [5 rows x 80 columns]

# %%
warnings(X_p)
# Out:
# +------------+
# |  Warnings  |
# +------------+

# %%
from henchman.learning import inplace_encoder, create_holdout, create_model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
import numpy as np
splits = 5
scores, fit_model = create_model(X, y, RandomForestClassifier(), roc_auc_score, n_splits=splits)
print('Average score of {:.2f} over {} splits (stdev {:.3f})'.format(np.mean(scores), splits, np.std(scores)))
# Out:
# Average score of 0.81 over 5 splits (stdev 0.036)

# %%
scores, fit_model2 = create_model(X_p, y, RandomForestClassifier(), roc_auc_score, n_splits=splits)
print('Average score of {:.2f} over {} splits (stdev {:.3f})'.format(np.mean(scores), splits, np.std(scores)))
# Out:
# Average score of 0.79 over 5 splits (stdev 0.051)

# %%
show(feature_importances(X_p, fit_model2, n_feats=10), height=300)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3354fcc4-23df-4b24-95c9-ac7bba3cd80f">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="92ad2588-1072-4f40-83c6-548b496be8c7"></div>

# %%
show(histogram(X['MAX(orders.SUM(order_products.total))'], y, col_max=5000))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-8790a724f488> in <module>()
# ----> 1 show(histogram(X['MAX(orders.SUM(order_products.total))'], y, col_max=5000))
#
# ~/Documents/Repositories/henchman/henchman/plotting.py in show(plot, png, width, height, title, x_axis, y_axis, x_range, y_range)
#     136                'title': title, 'x_axis': x_axis, 'y_axis': y_axis,
#     137                'x_range': x_range, 'y_range': y_range}
# --> 138     figure = plot(figargs=figargs)
#     139
#     140     if png:
#
# ~/Documents/Repositories/henchman/henchman/plotting.py in <lambda>(figargs)
#     232         return lambda figargs: histogram(
#     233             col, y, n_bins, col_max, col_min,
# --> 234             normalized, hover, static, figargs=figargs)
#     235
#     236     source = ColumnDataSource(_make_histogram_source(col, y, n_bins, col_max, col_min, normalized))
#
# ~/Documents/Repositories/henchman/henchman/plotting.py in histogram(col, y, n_bins, col_max, col_min, normalized, hover, static, figargs)
#     234             normalized, hover, static, figargs=figargs)
#     235
# --> 236     source = ColumnDataSource(_make_histogram_source(col, y, n_bins, col_max, col_min, normalized))
#     237     plot = _make_histogram_plot(y, hover, source)
#     238     plot = _modify_plot(plot, figargs)
#
# ~/Documents/Repositories/henchman/henchman/plotting.py in _make_histogram_source(col, y, n_bins, col_max, col_min, normalized)
#     785     if y is not None:
#     786         label_hist = np.nan_to_num(cols['label'].groupby(
# --> 787             pd.cut(col, edges, right=False)).sum().values, 0)
#     788         if normalized:
#     789             label_hist = label_hist / (label_hist.sum() * (edges[1] - edges[0]))
#
# TypeError: nan_to_num() takes 1 positional argument but 2 were given

# %%
from henchman.plotting import roc_auc
show(roc_auc(X_p, y, RandomForestClassifier(), n_splits=splits), height=400, width=400)

# %%
from henchman.plotting import f1
show(f1(X_p, y, RandomForestClassifier(), n_splits=splits), height=400, width=400)

# %%
import numpy as np
np.__version__
# Out:
# '1.11.3'

# %%
pd.__version__
# Out:
# '0.23.1'
